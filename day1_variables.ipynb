# %%
# YOUR TURN - Fill in your info
your_name = "EBBP"
your_age = 25
your_country = "Russia"
years_in_ai = 0
favorite_model = "EZ"
current_goal = "Total mastering of AI"
uses_gpu = True
daily_coding_hours = 8
favorite_dataset = "Bulu"
loves_coffee = True

# Print bio (3 sentences)
print(f"I'm {your_name}, {your_age} years old from {your_country}.")
print(f"I have {years_in_ai} year(s) in AI, my favorite model is {favorite_model}, my goal is {current_goal}.")
print(f"It's {uses_gpu} I will be using GPU, planning on daily {daily_coding_hours} hour(s) coding. My favorite dataset is {favorite_dataset}. it's {loves_coffee} I love coffee.")
# Out:
# I'm EBBP, 25 years old from Russia.
# I have 0 year(s) in AI, my favorite model is EZ, my goal is Total mastering of AI.
# It's True I will be using GPU, planning on daily 8 hour(s) coding. My favorite dataset is Bulu. it's True I love coffee.

# %%
# Model config
model_name = "ResNet-50"
learning_rate = 0.001
batch_size = 32
epochs = 100
optimizer = "Adam"
use_pretrained = True
dataset = "ImageNet"

# Print config card
print(f"""
AI MODEL CONFIGURATION
{'='*40}
Model: {model_name}
LR: {learning_rate}
Batch: {batch_size}
Epochs: {epochs}
Optimizer: {optimizer}
Pretrained: {use_pretrained}
Dataset: {dataset}
{'='*40}
""")
# Out:
# AI MODEL CONFIGURATION
# ...
# Model: ResNet-50
# LR: 0.001
# Batch: 32
# Epochs: 100
# Optimizer: Adam
# Pretrained: True
# Dataset: ImageNet
# ...

# %%
# Convert between types
age_str = "25"
learning_rate = 0.0005

# Convert age_str to int
age_int = int(age_str)

# Convert learning_rate to string with 6 decimals
lr_str = f"{learning_rate:.6f}"

# Combine in sentence
print(f"I am {age_int} years old. My LR is {lr_str}.")
# Out:
# I am 25 years old. My LR is 0.000500.
